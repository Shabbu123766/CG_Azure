# %%
# Scenario
# A student is building a simple AI assistant in Google Colab for a class project. The assistant is
# hosted on Azure Foundry, and the student wants to ask it questions like:

# “What can you help with?”

# “Explain this topic simply.”

# “Give me a short summary.”

# Instead of talking directly to the model through a chat app, the student uses Python code to connect to the Azure service.

from google.colab import userdata

api_key = userdata.get("open_api_key")
print("Loaded key:", api_key[:6] + "..." if api_key else "Missing")

from google.colab import userdata
from openai import OpenAI

my_endpoint = "https://shabbu456.services.ai.azure.com/api/projects/proj-default"
my_agent = "email-assistant"
my_version = "3"

api_key = userdata.get("open_api_key")

openai_client = OpenAI(
    base_url=f"{my_endpoint}/openai/v1",
    api_key=api_key
)

response = openai_client.responses.create(
    input=[{"role": "user", "content": "Tell me what you can help with."}],
    extra_body={
        "agent_reference": {
            "name": my_agent,
            "version": my_version,
            "type": "agent_reference"
        }
    },
)

print(response.output_text)
# Out:
# Loaded key: 9FFvyH...
# I can assist you with a variety of email-related tasks, including:
#
# - Composing new emails for different professional scenarios (e.g., making requests, sending apologies, confirming meetings, or responding to inquiries).
# - Editing and refining your draft emails to ensure clarity, professionalism, and a gentle, kind tone.
# - Providing suggestions for subject lines to increase the effectiveness of your communication.
# - Formatting emails for readability and impact, including proper greetings, sign-offs, and any required attachments or references.
# - Offering templates for common business situations, such as follow-ups, thank you notes, or reminders.
#
# If you have a specific situation or a draft you’d like to work on, just let me know, and I’ll be happy to help.
